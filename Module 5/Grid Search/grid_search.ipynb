# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"

# %%
df = pd.read_csv(file_path, header=0)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
# Grid Search
parameters = [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 1000000]}]

RidgeModel = Ridge()
Grid = GridSearchCV(RidgeModel, parameters, cv=4)
Grid.fit(df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], df.price)

Grid.best_estimator_
scores = Grid.cv_results_
scores['mean_test_score']
# Out:
# array([0.66459248, 0.66459305, 0.66459827, 0.66465008, 0.66513615,
#        0.66808959, 0.67249168, 0.6569726 , 0.60142652])

# %%
# Grid Search with different combinations of parameters
parameters1 = [{
    'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 1000000]
}]

RidgeModel1 = Ridge()
Grid1 = GridSearchCV(RidgeModel1, parameters1, cv=4)
Grid1.fit(df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], df.price)

Grid1.best_estimator_
scores1 = Grid1.cv_results_

for param, mean_val in zip(scores1['params'], scores1['mean_test_score']):
    print(param, "R^2 on test data: ", mean_val)
# Out:
# {'alpha': 0.001} R^2 on test data:  0.6645924797281765
# {'alpha': 0.1} R^2 on test data:  0.6645930537608065
# {'alpha': 1} R^2 on test data:  0.6645982687663077
# {'alpha': 10} R^2 on test data:  0.6646500769756496
# {'alpha': 100} R^2 on test data:  0.6651361463299668
# {'alpha': 1000} R^2 on test data:  0.6680895877166882
# {'alpha': 10000} R^2 on test data:  0.6724916803148251
# {'alpha': 100000} R^2 on test data:  0.6569725965962285
# {'alpha': 1000000} R^2 on test data:  0.6014265199878485
